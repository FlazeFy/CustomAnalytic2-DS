# %%
import matplotlib.pyplot as plt

# Aircraft Count Distribution by Side
# Response
data = {
    "message": "Aircraft found",
    "status": "success",
    "data": [
        {"context": "Allies", "total": 177},
        {"context": "Axis", "total": 166}
    ]
}

if data and data.get("status") == "success":
    # Dataset
    sides = [item["context"] for item in data["data"]]
    totals = [item["total"] for item in data["data"]]

    # Pie Chart
    plt.figure(figsize=(8, 8))
    plt.pie(
        totals, 
        labels=sides, 
        autopct='%1.1f%%', 
        startangle=140, 
    )
    plt.title("Aircraft Count Distribution by Side")
    plt.show()
else:
    print("No valid data to display!")

# Aircraft Count Distribution by Role
# Response
data = {
    "message": "Aircraft found",
    "status": "success",
    "data": [
        {
            "context": "Fighter",
            "total": 76
        },
        {
            "context": "Medium Bomber",
            "total": 43
        },
        {
            "context": "Seaplane",
            "total": 41
        },
        {
            "context": "Other",
            "total": 31
        },
        {
            "context": "Transport",
            "total": 25
        },
        {
            "context": "Torpedo Bomber",
            "total": 18
        },
        {
            "context": "Heavy Bomber",
            "total": 15
        }
    ]
}

if data and data.get("status") == "success":
    # Dataset
    sides = [item["context"] for item in data["data"]]
    totals = [item["total"] for item in data["data"]]

    # Pie Chart
    plt.figure(figsize=(8, 8))
    plt.pie(
        totals, 
        labels=sides, 
        autopct='%1.1f%%', 
        startangle=140, 
    )
    plt.title("Aircraft Count Distribution by Role")
    plt.show()
else:
    print("No valid data to display!")

# Aircraft Count Distribution by Country
# Response
data = {
    "message": "Aircraft found",
    "status": "success",
    "data": [
        {
            "context": "United States",
            "total": 75
        },
        {
            "context": "Japan",
            "total": 73
        },
        {
            "context": "Germany",
            "total": 54
        },
        {
            "context": "United Kingdom",
            "total": 48
        },
        {
            "context": "Italy",
            "total": 38
        },
        {
            "context": "Russia",
            "total": 25
        },
        {
            "context": "France",
            "total": 15
        }
    ]
}

if data and data.get("status") == "success":
    # Dataset
    sides = [item["context"] for item in data["data"]]
    totals = [item["total"] for item in data["data"]]

    # Pie Chart
    plt.figure(figsize=(8, 8))
    plt.pie(
        totals, 
        labels=sides, 
        autopct='%1.1f%%', 
        startangle=140, 
    )
    plt.title("Aircraft Count Distribution by Country")
    plt.show()
else:
    print("No valid data to display!")
